# %%
from pandas import Series
from pandas import DataFrame
from pandas import concat
import pandas as pd
import os

# %%
merged_dataset = pd.read_csv("D:\\COLLEGE\\THESIS\Feature Engineering\\FeatureEngineering_TimeSeries\\normalized_merged\\normalized_mmda_ogimet_2015_seasonDryWet_ENGINEERED\\ENGINEER_normalized_mmda_ogimet_A. Maceda_2015_seasonDry.csv", skipinitialspace = True, encoding = "ISO-8859-1")
correlation = merged_dataset.corr(method='spearman')
correlation.head()
# Out:
#                statusN   statusS  temperatureC  dewpointC  windspeedKMH  \
# statusN       1.000000  0.264077      0.148402   0.055052      0.131430
# statusS       0.264077  1.000000      0.202016   0.047613      0.216460
# temperatureC  0.148402  0.202016      1.000000   0.491295      0.518913
# dewpointC     0.055052  0.047613      0.491295   1.000000      0.107352
# windspeedKMH  0.131430  0.216460      0.518913   0.107352      1.000000
#
#               pressureMB  pressureTendencyMB  cloudCoverOKTA  \
# statusN         0.006044           -0.066189        0.078320
# statusS         0.002765            0.062853       -0.002792
# temperatureC   -0.523481           -0.208920       -0.187290
# dewpointC      -0.557906           -0.071394        0.099297
# windspeedKMH   -0.227751           -0.143521        0.047949
#
#               lowCloudCoverOKTA  HKm             ...              \
# statusN                0.074652  NaN             ...
# statusS                0.006400  NaN             ...
# temperatureC          -0.027951  NaN             ...
# dewpointC              0.147539  NaN             ...
# windspeedKMH           0.110538  NaN             ...
#
#               Expanding Sum 24 precipMM  Expanding Mean 24 precipMM  \
# statusN                        0.035306                    0.035272
# statusS                        0.019035                    0.018715
# temperatureC                  -0.132373                   -0.132376
# dewpointC                      0.160539                    0.160499
# windspeedKMH                   0.030816                    0.031811
#
#               Expanding Min 48 precipMM  Expanding Max 48 precipMM  \
# statusN                        0.037668                   0.019706
# statusS                        0.029119                   0.005423
# temperatureC                  -0.146211                  -0.110262
# dewpointC                      0.080624                   0.182932
# windspeedKMH                   0.077045                   0.024367
#
#               Expanding Sum 48 precipMM  Expanding Mean 48 precipMM  \
# statusN                        0.018320                    0.020190
# statusS                        0.004878                    0.005672
# temperatureC                  -0.110522                   -0.111340
# dewpointC                      0.182941                    0.183287
# windspeedKMH                   0.023399                    0.024776
#
#               Expanding Min 96 precipMM  Expanding Max 96 precipMM  \
# statusN                        0.065645                  -0.019215
# statusS                        0.021853                   0.003072
# temperatureC                  -0.120103                  -0.196176
# dewpointC                      0.053676                   0.172929
# windspeedKMH                   0.077821                  -0.106819
#
#               Expanding Sum 96 precipMM  Expanding Mean 96 precipMM
# statusN                       -0.021180                   -0.015383
# statusS                        0.001264                    0.006156
# temperatureC                  -0.199127                   -0.194347
# dewpointC                      0.171029                    0.173550
# windspeedKMH                  -0.109115                   -0.102507
#
# [5 rows x 444 columns]

# %%
path = 'D:\\COLLEGE\\THESIS\\Feature Engineering\\FeatureEngineering_TimeSeries\\normalized_merged\\normalized_mmda_wwo_2015_seasonDryWet'
ogpath = path + "_ENGINEERED\\"
for pfilename in os.listdir(ogpath):
    print(pfilename)
    filename = pfilename
    merged_dataset = pd.read_csv(ogpath + filename, skipinitialspace = True, encoding = "ISO-8859-1")
    correlation = merged_dataset.corr(method='spearman')
    correlation.to_csv(path + "_CORRELATED\\CORRELATED_" + filename, encoding='utf-8', index=False)
  
print('DONE')
# Out:
# ENGINEER_normalized_mmda_wwo_A. Maceda_2015_seasonDry.csv
# ENGINEER_normalized_mmda_wwo_A. Maceda_2015_seasonWet.csv
# ENGINEER_normalized_mmda_wwo_Anda Circle_2015_seasonDry.csv
# ENGINEER_normalized_mmda_wwo_Anda Circle_2015_seasonWet.csv
# ENGINEER_normalized_mmda_wwo_Antipolo_2015_seasonDry.csv
# ENGINEER_normalized_mmda_wwo_Antipolo_2015_seasonWet.csv
# ENGINEER_normalized_mmda_wwo_Bluementritt_2015_seasonDry.csv
# ENGINEER_normalized_mmda_wwo_Bluementritt_2015_seasonWet.csv
# ENGINEER_normalized_mmda_wwo_Buendia_2015_seasonDry.csv
# ENGINEER_normalized_mmda_wwo_Buendia_2015_seasonWet.csv
# ENGINEER_normalized_mmda_wwo_Edsa Extension_2015_seasonDry.csv
# ENGINEER_normalized_mmda_wwo_Edsa Extension_2015_seasonWet.csv
# ENGINEER_normalized_mmda_wwo_Finance Road_2015_seasonDry.csv
# ENGINEER_normalized_mmda_wwo_Finance Road_2015_seasonWet.csv
# ENGINEER_normalized_mmda_wwo_Gov. Forbes - Lacson_2015_seasonDry.csv
# ENGINEER_normalized_mmda_wwo_Gov. Forbes - Lacson_2015_seasonWet.csv
# ENGINEER_normalized_mmda_wwo_Lerma_2015_seasonDry.csv
# ENGINEER_normalized_mmda_wwo_Lerma_2015_seasonWet.csv
# ENGINEER_normalized_mmda_wwo_Magsaysay Ave_2015_seasonDry.csv
# ENGINEER_normalized_mmda_wwo_Magsaysay Ave_2015_seasonWet.csv
# ENGINEER_normalized_mmda_wwo_P.Noval_2015_seasonDry.csv
# ENGINEER_normalized_mmda_wwo_P.Noval_2015_seasonWet.csv
# ENGINEER_normalized_mmda_wwo_Pablo Ocampo_2015_seasonDry.csv
# ENGINEER_normalized_mmda_wwo_Pablo Ocampo_2015_seasonWet.csv
# ENGINEER_normalized_mmda_wwo_Pedro Gil_2015_seasonDry.csv
# ENGINEER_normalized_mmda_wwo_Pedro Gil_2015_seasonWet.csv
# ENGINEER_normalized_mmda_wwo_Quezon Ave._2015_seasonDry.csv
# ENGINEER_normalized_mmda_wwo_Quezon Ave._2015_seasonWet.csv
# ENGINEER_normalized_mmda_wwo_Quirino_2015_seasonDry.csv
# ENGINEER_normalized_mmda_wwo_Quirino_2015_seasonWet.csv
# ENGINEER_normalized_mmda_wwo_Rajah Sulayman_2015_seasonDry.csv
# ENGINEER_normalized_mmda_wwo_Rajah Sulayman_2015_seasonWet.csv
# ENGINEER_normalized_mmda_wwo_Taft Ave._2015_seasonDry.csv
# ENGINEER_normalized_mmda_wwo_Taft Ave._2015_seasonWet.csv
# ENGINEER_normalized_mmda_wwo_U.N. Avenue_2015_seasonDry.csv
# ENGINEER_normalized_mmda_wwo_U.N. Avenue_2015_seasonWet.csv
# ENGINEER_normalized_mmda_wwo_Vicente Cruz_2015_seasonDry.csv
# ENGINEER_normalized_mmda_wwo_Vicente Cruz_2015_seasonWet.csv
# normalized_mmda_wwo_A. Maceda_2015_seasonDry.csv
# normalized_mmda_wwo_A. Maceda_2015_seasonWet.csv
# normalized_mmda_wwo_Anda Circle_2015_seasonDry.csv
# normalized_mmda_wwo_Anda Circle_2015_seasonWet.csv
# normalized_mmda_wwo_Antipolo_2015_seasonDry.csv
# DONE
