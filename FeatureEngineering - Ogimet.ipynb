# %%
#SIMPLE DATA READING
from pandas import Series
from pandas import DataFrame
from pandas import concat
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import minmax_scale

# %%
def generateFeatures(variable):

    # Generate Shifts
    series[variable + '_t-10'] = series[variable].shift(10)
    series[variable + '_t-9'] = series[variable].shift(9)
    series[variable + '_t-8'] = series[variable].shift(8)
    series[variable + '_t-7'] = series[variable].shift(7)
    series[variable + '_t-6'] = series[variable].shift(6)
    series[variable + '_t-5'] = series[variable].shift(5)
    series[variable + '_t-4'] = series[variable].shift(4)
    series[variable + '_t-3'] = series[variable].shift(3)
    series[variable + '_t-2'] = series[variable].shift(2)
    series[variable + '_t-1'] = series[variable].shift(1)
    series[variable + '_t'] = series[variable]


    #Expanding Part
    expandingWindow = series[variable].expanding()

    expandingWidth = 5
    expandingMeans = expandingWindow.mean()
    expandingMins = expandingWindow.min()
    expandingMaxs = expandingWindow.max()
    expandingSum = expandingWindow.sum()
    series[variable + '_Emean'] = expandingMeans
    series[variable + '_Emin'] = expandingMins
    series[variable + '_Emax'] = expandingMaxs
    series[variable + '_Esum'] = expandingSum


    
    # Rolling Window Features window 3 = 30mins

    rolllingWidth = 3
    rolllingWindow = series[variable + '_t-2'].rolling(window=rolllingWidth)
    rollingMeans = rolllingWindow.mean()
    rollingMins = rolllingWindow.min()
    rollingMaxs = rolllingWindow.max()
    rollingMaxs = rolllingWindow.sum()
    series[variable + '_Rmean (window = 3)'] = rollingMeans
    series[variable + '_Rmin  (window = 3)'] = rollingMins
    series[variable + '_Rmax  (window = 3)'] = rollingMaxs

    # Rolling Window Features window 5 = 1hr

    rolllingWidth = 5
    rolllingWindow = series[variable + '_t-4'].rolling(window=rolllingWidth)
    rollingMeans = rolllingWindow.mean()
    rollingMins = rolllingWindow.min()
    rollingMaxs = rolllingWindow.max()
    rollingMaxs = rolllingWindow.sum()
    series[variable + '_Rmean (window = 5)'] = rollingMeans
    series[variable + '_Rmin  (window = 5)'] = rollingMins
    series[variable + '_Rmax  (window = 5)'] = rollingMaxs

    # Rolling Window Features window 7 = 1hr 30mins

    rolllingWidth = 7
    rolllingWindow = series[variable + '_t-6'].rolling(window=rolllingWidth)
    rollingMeans = rolllingWindow.mean()
    rollingMins = rolllingWindow.min()
    rollingMaxs = rolllingWindow.max()
    rollingMaxs = rolllingWindow.sum()
    series[variable + '_Rmean (window = 7)'] = rollingMeans
    series[variable + '_Rmin  (window = 7)'] = rollingMins
    series[variable + '_Rmax  (window = 7)'] = rollingMaxs

    
    # Rolling Window Features window 9 = 2hrs

    rolllingWidth = 9
    rolllingWindow = series[variable + '_t-8'].rolling(window=rolllingWidth)
    rollingMeans = rolllingWindow.mean()
    rollingMins = rolllingWindow.min()
    rollingMaxs = rolllingWindow.max()
    rollingMaxs = rolllingWindow.sum()
    series[variable + '_Rmean (window = 9)'] = rollingMeans
    series[variable + '_Rmin  (window = 9)'] = rollingMins
    series[variable + '_Rmax  (window = 9)'] = rollingMaxs

# %%
def generateFeaturesWOshift(variable):

    # Generate Shifts
    
    t17 = series[variable].shift(17).fillna(0)
    t16 = series[variable].shift(16).fillna(0)
    t15 = series[variable].shift(15).fillna(0)
    t14 = series[variable].shift(14).fillna(0)
    t13 = series[variable].shift(13).fillna(0)
    t12 = series[variable].shift(12).fillna(0)
    t11 = series[variable].shift(11).fillna(0)
    t10 = series[variable].shift(10).fillna(0)
    t9 = series[variable].shift(9).fillna(0)
    t8 = series[variable].shift(8).fillna(0)
    t7 = series[variable].shift(7).fillna(0)
    t6 = series[variable].shift(6).fillna(0)
    t5 = series[variable].shift(5).fillna(0)
    t4 = series[variable].shift(4).fillna(0)
    t3 = series[variable].shift(3).fillna(0)
    t2 = series[variable].shift(2).fillna(0)
    t1 = series[variable].shift(1).fillna(0)
    t = series[variable]
    
    #Expanding Part
    expandingWindow = series[variable].expanding()

    
    expandingMeans = expandingWindow.mean()
    expandingMins = expandingWindow.min()
    expandingMaxs = expandingWindow.max()
    expandingSum = expandingWindow.sum()
    series[variable + '_Emean'] = expandingMeans.fillna(0)
    series[variable + '_Emin'] = expandingMins.fillna(0)
    series[variable + '_Emax'] = expandingMaxs.fillna(0)
    series[variable + '_Esum'] = expandingSum.fillna(0)

    # Rolling Window Features window 2 = 15mins

    rolllingWidth = 2
    rolllingWindow = t1.rolling(window=rolllingWidth)
    rollingMeans = rolllingWindow.mean()
    rollingMins = rolllingWindow.min()
    rollingMaxs = rolllingWindow.max()
    rollingMaxs = rolllingWindow.sum()
    series[variable + '_Rmean (window = 2)'] = rollingMeans
    series[variable + '_Rmin  (window = 2)'] = rollingMins
    series[variable + '_Rmax  (window = 2)'] = rollingMaxs

    
    # Rolling Window Features window 3 = 30mins

    rolllingWidth = 3
    rolllingWindow = t2.rolling(window=rolllingWidth)
    rollingMeans = rolllingWindow.mean()
    rollingMins = rolllingWindow.min()
    rollingMaxs = rolllingWindow.max()
    series[variable + '_Rmean (window = 3)'] = rollingMeans.fillna(0)
    series[variable + '_Rmin  (window = 3)'] = rollingMins.fillna(0)
    series[variable + '_Rmax  (window = 3)'] = rollingMaxs.fillna(0)

    # Rolling Window Features window 4 = 15mins

    rolllingWidth = 4
    rolllingWindow = t3.rolling(window=rolllingWidth)
    rollingMeans = rolllingWindow.mean()
    rollingMins = rolllingWindow.min()
    rollingMaxs = rolllingWindow.max()
    rollingMaxs = rolllingWindow.sum()
    series[variable + '_Rmean (window = 4)'] = rollingMeans
    series[variable + '_Rmin  (window = 4)'] = rollingMins
    series[variable + '_Rmax  (window = 4)'] = rollingMaxs

    
    # Rolling Window Features window 5 = 1hr

    rolllingWidth = 5
    rolllingWindow = t4.rolling(window=rolllingWidth)
    rollingMeans = rolllingWindow.mean()
    rollingMins = rolllingWindow.min()
    rollingMaxs = rolllingWindow.max()
    series[variable + '_Rmean (window = 5)'] = rollingMeans.fillna(0)
    series[variable + '_Rmin  (window = 5)'] = rollingMins.fillna(0)
    series[variable + '_Rmax  (window = 5)'] = rollingMaxs.fillna(0)

#     # Rolling Window Features window 6 = 1hr 15mins

#     rolllingWidth = 6
#     rolllingWindow = t5.rolling(window=rolllingWidth)
#     rollingMeans = rolllingWindow.mean()
#     rollingMins = rolllingWindow.min()
#     rollingMaxs = rolllingWindow.max()
#     series[variable + '_Rmean (window = 6)'] = rollingMeans.fillna(0)
#     series[variable + '_Rmin  (window = 6)'] = rollingMins.fillna(0)
#     series[variable + '_Rmax  (window = 6)'] = rollingMaxs.fillna(0)
    
#     # Rolling Window Features window 7 = 1hr 30mins

#     rolllingWidth = 7
#     rolllingWindow = t6.rolling(window=rolllingWidth)
#     rollingMeans = rolllingWindow.mean()
#     rollingMins = rolllingWindow.min()
#     rollingMaxs = rolllingWindow.max()
#     series[variable + '_Rmean (window = 7)'] = rollingMeans.fillna(0)
#     series[variable + '_Rmin  (window = 7)'] = rollingMins.fillna(0)
#     series[variable + '_Rmax  (window = 7)'] = rollingMaxs.fillna(0)

    
#     # Rolling Window Features window 8 = 1hr 45mins

#     rolllingWidth = 8
#     rolllingWindow = t7.rolling(window=rolllingWidth)
#     rollingMeans = rolllingWindow.mean()
#     rollingMins = rolllingWindow.min()
#     rollingMaxs = rolllingWindow.max()
#     series[variable + '_Rmean (window = 8)'] = rollingMeans.fillna(0)
#     series[variable + '_Rmin  (window = 8)'] = rollingMins.fillna(0)
#     series[variable + '_Rmax  (window = 8)'] = rollingMaxs.fillna(0)
    
#     # Rolling Window Features window 9 = 2hrs

#     rolllingWidth = 9
#     rolllingWindow = t8.rolling(window=rolllingWidth)
#     rollingMeans = rolllingWindow.mean()
#     rollingMins = rolllingWindow.min()
#     rollingMaxs = rolllingWindow.max()
#     series[variable + '_Rmean (window = 9)'] = rollingMeans.fillna(0)
#     series[variable + '_Rmin  (window = 9)'] = rollingMins.fillna(0)
#     series[variable + '_Rmax  (window = 9)'] = rollingMaxs.fillna(0)
    
    
#     # Rolling Window Features window 10 = 2hrs 15mins

#     rolllingWidth = 10
#     rolllingWindow = t9.rolling(window=rolllingWidth)
#     rollingMeans = rolllingWindow.mean()
#     rollingMins = rolllingWindow.min()
#     rollingMaxs = rolllingWindow.max()
#     series[variable + '_Rmean (window = 10)'] = rollingMeans.fillna(0)
#     series[variable + '_Rmin  (window = 10)'] = rollingMins.fillna(0)
#     series[variable + '_Rmax  (window = 10)'] = rollingMaxs.fillna(0)
    
    
#     #Rolling Window Features window 11 = 2hrs 30mins

#     rolllingWidth = 11
#     rolllingWindow = t10.rolling(window=rolllingWidth)
#     rollingMeans = rolllingWindow.mean()
#     rollingMins = rolllingWindow.min()
#     rollingMaxs = rolllingWindow.max()
#     series[variable + '_Rmean (window = 11)'] = rollingMeans.fillna(0)
#     series[variable + '_Rmin  (window = 11)'] = rollingMins.fillna(0)
#     series[variable + '_Rmax  (window = 11)'] = rollingMaxs.fillna(0)
    
#     # Rolling Window Features window 12 = 2hrs 45mins

#     rolllingWidth = 12
#     rolllingWindow = t10.rolling(window=rolllingWidth)
#     rollingMeans = rolllingWindow.mean()
#     rollingMins = rolllingWindow.min()
#     rollingMaxs = rolllingWindow.max()
#     series[variable + '_Rmean (window = 10)'] = rollingMeans.fillna(0)
#     series[variable + '_Rmin  (window = 10)'] = rollingMins.fillna(0)
#     series[variable + '_Rmax  (window = 10)'] = rollingMaxs.fillna(0)
    
#     # Rolling Window Features window 13 = 3hrs

#     rolllingWidth = 13
#     rolllingWindow = t12.rolling(window=rolllingWidth)
#     rollingMeans = rolllingWindow.mean()
#     rollingMins = rolllingWindow.min()
#     rollingMaxs = rolllingWindow.max()
#     series[variable + '_Rmean (window = 13)'] = rollingMeans.fillna(0)
#     series[variable + '_Rmin  (window = 13)'] = rollingMins.fillna(0)
#     series[variable + '_Rmax  (window = 13)'] = rollingMaxs.fillna(0)

    
#     # Rolling Window Features window 14 = 3hrs 15mins

#     rolllingWidth = 14
#     rolllingWindow = t13.rolling(window=rolllingWidth)
#     rollingMeans = rolllingWindow.mean()
#     rollingMins = rolllingWindow.min()
#     rollingMaxs = rolllingWindow.max()
#     series[variable + '_Rmean (window = 14)'] = rollingMeans.fillna(0)
#     series[variable + '_Rmin  (window = 14)'] = rollingMins.fillna(0)
#     series[variable + '_Rmax  (window = 14)'] = rollingMaxs.fillna(0)
    
    
#     # Rolling Window Features window 15 = 3hrs30mins

#     rolllingWidth = 15
#     rolllingWindow = t14.rolling(window=rolllingWidth)
#     rollingMeans = rolllingWindow.mean()
#     rollingMins = rolllingWindow.min()
#     rollingMaxs = rolllingWindow.max()
#     series[variable + '_Rmean (window = 15)'] = rollingMeans.fillna(0)
#     series[variable + '_Rmin  (window = 15)'] = rollingMins.fillna(0)
#     series[variable + '_Rmax  (window = 15)'] = rollingMaxs.fillna(0)
    
#     # Rolling Window Features window 15 = 3hrs 45mins

#     rolllingWidth = 16
#     rolllingWindow = t15.rolling(window=rolllingWidth)
#     rollingMeans = rolllingWindow.mean()
#     rollingMins = rolllingWindow.min()
#     rollingMaxs = rolllingWindow.max()
#     series[variable + '_Rmean (window = 16)'] = rollingMeans.fillna(0)
#     series[variable + '_Rmin  (window = 16)'] = rollingMins.fillna(0)
#     series[variable + '_Rmax  (window = 16)'] = rollingMaxs.fillna(0)
    
#     # Rolling Window Features window 17 = 4hrs

#     rolllingWidth = 17
#     rolllingWindow = t16.rolling(window=rolllingWidth)
#     rollingMeans = rolllingWindow.mean()
#     rollingMins = rolllingWindow.min()
#     rollingMaxs = rolllingWindow.max()
#     series[variable + '_Rmean (window = 17)'] = rollingMeans.fillna(0)
#     series[variable + '_Rmin  (window = 17)'] = rollingMins.fillna(0)
#     series[variable + '_Rmax  (window = 17)'] = rollingMaxs.fillna(0)

# %%
from sklearn.preprocessing import MinMaxScaler

def normalize(data):
    y = pd.to_numeric(data)
    y = np.array(y.reshape(-1, 1))
    scaler = MinMaxScaler()
    y = scaler.fit_transform(y)
    y = y.reshape(1, -1)[0]
    return y

# %%
for filename in os.listdir('D:\\COLLEGE\\THESIS\\Feature Engineering\\Weather - OGIMET\\Weather - OGIMET\\'):
    print(filename)
    series = pd.read_csv("D:\\COLLEGE\\THESIS\\Feature Engineering\\Weather - OGIMET\\Weather - OGIMET\\" + filename, skipinitialspace = True, encoding = "ISO-8859-1")
    for v in range(1,11):
        variable = series.columns.values[v]
#         print(variable)
        series[variable] = normalize(series[variable])
        generateFeaturesWOshift(variable)
#     for v in range(6,12):
#         variable = series.columns.values[v]
#         generateFeaturesWOshift(variable)
    series.to_csv("D:\\COLLEGE\\THESIS\\Feature Engineering\\Weather - OGIMET\\Engineered\\Engineered_" + filename, encoding='utf-8', index=False)

    
    
    
# series = pd.read_csv("D:\\COLLEGE\\THESIS\\Feature Engineering\\merged_mmda_weatherforyou_manila_2015_bystation\\" + 'merged_mmda_weatherforyou_Taft Ave._2015.csv', skipinitialspace = True)
# for v in range(2,4):
#         variable = series.columns.values[v]
#         generateFeaturesWOshift(variable)
# for v in range(6,12):
#     variable = series.columns.values[v]
#     generateFeaturesWOshift(variable)
#     series.to_csv("D:\\COLLEGE\\THESIS\\Feature Engineering\\Engineered_NoNan_NoShift\\Engineered_NoShift_merged_mmda_weatherforyou_Taft Ave._2015.csv", encoding='utf-8', index=False)
# series
# Out:
# interpolated_weather_no_precip.csv
# C:\Users\nicol\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   """
# interpolated_weather_no_precip_2015.csv
# interpolated_weather_no_precip_2016.csv
# interpolated_weather_no_precip_2017.csv
# interpolated_weather_with_precip.csv
# interpolated_weather_with_precip_2015.csv
# interpolated_weather_with_precip_2016.csv
# interpolated_weather_with_precip_2017.csv
# weather_ogimet_2015.csv
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/src\inference.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "-----"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ...
